# %%
print("Hola ¿cómo estás?")
# Out:
# Hola ¿cómo estás?

# %%
4+3
# Out:
# 7

# %% [markdown]
# # Nivel 1
# ***EJECUTAMOS con CTRL ENTER***
# ## Nivel 2
# ### Nivel 3
# #### Nivel 4
# ###### Nivel 5

# %%
import pandas as pd

datos = pd.Series([100,200,300], index=["Juan", "Pedro", "Luis"])
datos.plot(ylabel="Ahorro", kind="pie")
# Out:
# <Axes: ylabel='Ahorro'>
