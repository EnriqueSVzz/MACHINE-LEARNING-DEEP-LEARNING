# %% [markdown]
# # Ejes en Matrices

# %%
import numpy as np

### Definimos un Array de 5x2
altura_pesos = np.array([
    [1.74,91.40],
    [1.80,88.70],
    [1.78,87.30],
    [1.68,62.70],
    [1.78,81.60]
    ])
print(altura_pesos.shape)
# Out:
# (5, 2)

# %% [markdown]
# ## Min y Max

# %%
### Este busca entre todos los valores y saca el mimino
print("Minimo:", altura_pesos.min())
### Igualmente pero este saca el máximo
print("Max:", altura_pesos.max())

### Te devuelven el index del minimo y maximo de todos estos valores
print("Posición Minimo:", altura_pesos.argmin())
print("Posición Maximo:", altura_pesos.argmax())
# Out:
# Minimo: 1.68
# Max: 91.4
# Posición Minimo: 6
# Posición Maximo: 1

# %% [markdown]
# ## Operaciones estadisticas

# %%
### Literal suma todos los valores
print("Suma:", altura_pesos.sum())
### Promedio de todos los valores
print("Promedio:", altura_pesos.mean())
# Out:
# Suma: 420.48
# Promedio: 42.048

# %% [markdown]
# ## Operaciones por eje.

# %% [markdown]
# * ***¿Cuál usar?***
#   - Normalmente se usa `.T` porque es más corto y más común.
#   - `.transpose()` se usa más cuando quieres especificar ejes (en NumPy 3D, por ejemplo).

# %%
### Es hacer lo mismo pero tenemos que hacerlo por eje
print("Minimo por Fila:", altura_pesos.min(axis=0))
print("Max por Fila:", altura_pesos.max(axis=0))
print("\nPosición Minimo por Fila :", altura_pesos.argmin(axis=0))
print("Posición Maximopor Fila:", altura_pesos.argmax(axis=0))
print("\nSuma por Fila:", altura_pesos.sum(axis=0))
print("Promedio por Fila:", altura_pesos.mean(axis=0))

### Transponer el arreglo (también se puede usar la .T)
print(altura_pesos.transpose())
print("\n",altura_pesos.T)
# Out:
# Minimo por Fila: [ 1.68 62.7 ]
# Max por Fila: [ 1.8 91.4]
#
# Posición Minimo por Fila : [3 3]
# Posición Maximopor Fila: [1 0]
#
# Suma por Fila: [  8.78 411.7 ]
# Promedio por Fila: [ 1.756 82.34 ]
# [[ 1.74  1.8   1.78  1.68  1.78]
#  [91.4  88.7  87.3  62.7  81.6 ]]
#
#  [[ 1.74  1.8   1.78  1.68  1.78]
#  [91.4  88.7  87.3  62.7  81.6 ]]
