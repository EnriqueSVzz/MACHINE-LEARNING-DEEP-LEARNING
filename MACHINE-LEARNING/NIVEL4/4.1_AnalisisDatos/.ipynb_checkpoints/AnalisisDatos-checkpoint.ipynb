# %% [markdown]
# # Análisis de Datos

# %%
import pandas as pd

# %% [markdown]
# ### Medidas de Tendencia Central

# %% [markdown]
# Principalmente son los siguiente:
# * Promedio o Media: sumar todo y dividir entre el total de elementos:
# * Mediana: tenemos que ordenar y seleccionar el de la posición central, si hay 2 empatados, se saca el promedio.
# * Moda: valor que se repite más en nuestra muestra.

# %% [markdown]
# ### Python

# %% [markdown]
# * `DataFrame.mean()`
# * `DataFrame.median()`
# * `DataFrame.mode`

# %%
goles = pd.DataFrame([0,3,3,0,8,1,1,0,0,1,5])
print(goles.mean(), goles.median(), goles.mode())
# Out:
# 0    2.0
# dtype: float64 0    1.0
# dtype: float64    0
# 0  0

# %% [markdown]
# ### Distribución Simétrica

# %% [markdown]
# * En una distribución simétrica (como la normal), la moda=mediana=media tienden a ser la punta de la campana.

# %% [markdown]
# ### Distribución Sesgada Positivamente (a la izquierda)

# %% [markdown]
# * Es como una montaña rusa, que empieza en un máximo y empieza a caer.
# * Aquí se sigue lo siguiente: Moda < Mediana < Media

# %% [markdown]
# ### Distribución Sesgada negativamente (a la derecha)

# %% [markdown]
# * Es como una montaña rusa, que empieza en un minimo y empieza a subir..
# * Aquí se sigue lo siguiente: Moda > Mediana > Media
